# %%
import soundfile
from espnet2.train.trainer import Trainer
from espnet2.tasks.asr import ASRTask
import argparse
from pathlib import Path
import yaml
from espnet2.train.distributed_utils import DistributedOption
from espnet2.utils.build_dataclass import build_dataclass
from espnet2.torch_utils.device_funcs import to_device

# %%
import soundfile as sfl

# %%
ckpt_path = '/data/anakuzne/espnet/egs2/librispeech_100/asr1/exp/asr_codec_frozen_full_lr2e-3_conv_input_large_batch_warmup15k_from_pretrained_num_enc_layers_1/71epoch.pth'
config_path = '/data/anakuzne/espnet/egs2/librispeech_100/asr1/exp/asr_codec_frozen_full_lr2e-3_conv_input_large_batch_warmup15k_from_pretrained_num_enc_layers_1/config.yaml'

# %%
task = ASRTask
model_latest, asr_train_args = task.build_model_from_file(
            config_path, ckpt_path, "cuda:7"
        )

# %%
with Path(config_path).open("r", encoding="utf-8") as f:
            args = yaml.safe_load(f)
args = argparse.Namespace(**args)

# %%
distributed_option = build_dataclass(DistributedOption, args)
# Setting distributed_option.dist_rank, etc.
distributed_option.init_options()

# %%
train_iter_factory = task.build_iter_factory(
                    args=args,
                    distributed_option=distributed_option,
                    mode="train",
                )

valid_iter_factory = task.build_iter_factory(
                    args=args,
                    distributed_option=distributed_option,
                    mode="valid",
                )

# %%
data_loader = train_iter_factory.build_iter(1000)
data_loader_valid = valid_iter_factory.build_iter(1000)

# %%
model_latest.eval()
avg_train_len = 0
for iiter, (utt_id, batch) in enumerate(data_loader):
    #batch = to_device(batch, "cuda:7")
    #print(batch["speech"].shape)
    #print(iiter, utt_id, batch)
    #retval = model_latest(**batch)
    #print("Train Loss ", retval[0])
    avg_train_len += batch['speech'].shape[1]
    
print(avg_train_len/len(data_loader))
# Out:
# 683.8096816976127

# %%
print(model_latest)
# Out:
# ESPnetASRModel(
#   (specaug): SpecAug(
#     (time_warp): TimeWarp(window=5, mode=bicubic)
#     (freq_mask): MaskAlongAxis(mask_width_range=[0, 27], num_mask=2, axis=freq)
#     (time_mask): MaskAlongAxisVariableMaxWidth(mask_width_ratio_range=[0.0, 0.05], num_mask=5, axis=time)
#   )
#   (normalize): UtteranceMVN(norm_means=True, norm_vars=False)
#   (encoder): ConformerEncoder(
#     (embed): Conv2dSubsampling(
#       (conv): Sequential(
#         (0): Conv2d(1, 256, kernel_size=(3, 3), stride=(2, 2))
#         (1): ReLU()
#         (2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2))
#         (3): ReLU()
#       )
#       (out): Sequential(
#         (0): Linear(in_features=65280, out_features=256, bias=True)
#         (1): RelPositionalEncoding(
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#     (encoders): MultiSequential(
#       (0): EncoderLayer(
#         (self_attn): RelPositionMultiHeadedAttention(
# ...

# %%
from encodec.model import EncodecModel
import torch
from collections import OrderedDict
import re
import torchaudio

# %%
model_path = "/data/anakuzne/encodec/ckpt/multi_encodec_3.amlt"
bandwidth = 3

model = EncodecModel._get_model(
                    target_bandwidths = [1.5, 3, 6], 
                    sample_rate = 16000,
                    channels  = 1,
                    causal  = True,
                    model_norm  = 'weight_norm',
                    audio_normalize  = False,
                    segment = None,
                    name = 'unset').to("cuda:7")
state_dict = torch.load(model_path)
model_dict = OrderedDict()
pattern = re.compile('module.')
for k,v in state_dict.items():
    if re.search("module", k):
        model_dict[re.sub(pattern, '', k)] = v
    else:
        model_dict = state_dict
model.load_state_dict(model_dict)
model.set_target_bandwidth(bandwidth)
model.eval()
# Out:
# /home/anakuzne/.local/lib/python3.8/site-packages/torch/nn/utils/weight_norm.py:28: UserWarning: torch.nn.utils.weight_norm is deprecated in favor of torch.nn.utils.parametrizations.weight_norm.
#   warnings.warn("torch.nn.utils.weight_norm is deprecated in favor of torch.nn.utils.parametrizations.weight_norm.")
# EncodecModel(
#   (encoder): SEANetEncoder(
#     (model): Sequential(
#       (0): SConv1d(
#         (conv): NormConv1d(
#           (conv): Conv1d(1, 32, kernel_size=(7,), stride=(1,))
#           (norm): Identity()
#         )
#       )
#       (1): SEANetResnetBlock(
#         (block): Sequential(
#           (0): ELU(alpha=1.0)
#           (1): SConv1d(
#             (conv): NormConv1d(
#               (conv): Conv1d(32, 16, kernel_size=(3,), stride=(1,))
#               (norm): Identity()
#             )
#           )
#           (2): ELU(alpha=1.0)
#           (3): SConv1d(
#             (conv): NormConv1d(
# ...

# %%
encoder = model.encoder
quantizer = model.quantizer

# %%
import IPython
IPython.display.Audio("/data/anakuzne/LibriSpeech/train-clean-100/27/123349/27-123349-0047.flac")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/flac;base64,..." type="audio/flac" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
input, sr = sfl.read("/data/anakuzne/LibriSpeech/train-clean-100/27/123349/27-123349-0047.flac")
input = torch.tensor(input).unsqueeze(0).unsqueeze(0).to("cuda:7")
z = encoder(input.float())
print(z)
quantizedResult = quantizer(z, frame_rate=16000) 
z = quantizedResult.quantized
print(z.min(), z.max())
# Out:
# tensor([[[ -0.2959,  -0.1522,  -0.0916,  ...,  -0.8122,  -0.7227,  -0.8455],
#          [  1.1211,   1.0955,   1.0037,  ...,   0.1040,   0.0582,   0.0264],
#          [  2.5062,   2.5125,   2.5627,  ...,   1.6987,   1.7007,   1.7484],
#          ...,
#          [  1.9409,   1.7983,   1.1978,  ...,   1.2838,   1.1694,   1.2625],
#          [-11.5048, -11.7995, -12.5016,  ...,  -8.8400,  -8.8736,  -8.9420],
#          [  0.7239,   0.2689,  -0.1068,  ...,  -0.0329,  -0.0668,  -0.0358]]],
#        device='cuda:7', grad_fn=<ConvolutionBackward0>)
# tensor(-14.1933, device='cuda:7') tensor(11.7242, device='cuda:7')

# %%
from espnet2.asr.frontend.default import DefaultFrontend
import matplotlib.pyplot as plt

# %%
z.shape
# Out:
# torch.Size([1, 128, 786])

# %%
plt.figure(figsize=(10, 8))
plt.imshow(z.squeeze(0).detach().cpu().numpy())

# %%
s_hat = model.decoder(z)

# %%
s_hat.shape
s_hat = s_hat.squeeze(0).squeeze(0).detach().cpu().numpy()

# %%
s_hat.shape
# Out:
# (251520,)

# %%
IPython.display.Audio(s_hat, rate=16000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
n_fft: 512
win_length: 400
hop_length: 160

# %%
frontend = DefaultFrontend(n_fft = 512, 
                           win_length = 400, 
                           hop_length = 160)

# %%
input_lens = torch.tensor(input.shape[-1]).to("cuda:7").unsqueeze(0)

# %%
input = input.squeeze(0)

# %%
input_lens
# Out:
# tensor([251520], device='cuda:7')

# %%
input = input.unsqueeze(0)

# %%
mel, mel_lens = frontend(input, input_lengths)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[121], line 1
# ----> 1 mel, mel_lens = frontend(input, input_lengths)
#
# File ~/.local/lib/python3.8/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
# ...

# %%
import dac

model_path = dac.utils.download(model_type="44khz")
model = dac.DAC.load(model_path)

model.to('cuda:6')
# Out:
# DAC(
#   (encoder): Encoder(
#     (block): Sequential(
#       (0): Conv1d(1, 64, kernel_size=(7,), stride=(1,), padding=(3,))
#       (1): EncoderBlock(
#         (block): Sequential(
#           (0): ResidualUnit(
#             (block): Sequential(
#               (0): Snake1d()
#               (1): Conv1d(64, 64, kernel_size=(7,), stride=(1,), padding=(3,))
#               (2): Snake1d()
#               (3): Conv1d(64, 64, kernel_size=(1,), stride=(1,))
#             )
#           )
#           (1): ResidualUnit(
#             (block): Sequential(
#               (0): Snake1d()
#               (1): Conv1d(64, 64, kernel_size=(7,), stride=(1,), padding=(9,), dilation=(3,))
#               (2): Snake1d()
#               (3): Conv1d(64, 64, kernel_size=(1,), stride=(1,))
#             )
#           )
#           (2): ResidualUnit(
#             (block): Sequential(
#               (0): Snake1d()
# ...

# %%
input = input.to("cuda:6")

# %%
z, codes, latents, _, _ = model.encode(input)

# %%
z.max()
# Out:
# tensor(20.0994, device='cuda:6', grad_fn=<MaxBackward1>)

# %%
plt.figure(figsize=(10, 8))
plt.imshow(z.squeeze(0).detach().cpu().numpy().T)

# %%
y = model.decode(z)

# %%
y = y.detach().cpu().squeeze(0).squeeze(0).numpy()

# %%
IPython.display.Audio(y, rate=16000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
